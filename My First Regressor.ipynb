# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score

wine = pd.read_csv('datasets/wine.csv')

# %%
X = wine.drop('pH', axis = 1)
y = wine['pH']

X_train, X_test, y_train, y_test =train_test_split(X, y)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

#GBR = GradientBoostingRegressor(loss = 'lad')

#GBR.fit(X_train, y_train)
#predicted = GBR.predict(X_test)

# %%
fig1 = plt.figure(1, figsize=(20,5))
chart1 = fig1.add_subplot(121)


xx = [3,4]
yy = [3,4]

chart1.set_xlabel('Actual Score')
chart1.set_ylabel('Predicted Score')

chart1.scatter(y_test,predicted)
chart1.plot(xx,yy)

# %%
pred_list = predicted.astype(list)
errors = []
y_test_list

GBR = GradientBoostingRegressor(loss = 'huber', alpha = 0.25, learning_rate = 0.1, n_estimators = 250, subsample = 1)

GBR.fit(X_train, y_train)
predicted = GBR.predict(X_test)

for _ in y_test:
    y_test_list.append(_)
    
count = 0
for _ in pred_list:
    error = pred_list[count] - y_test_list[count]
    errors.append(error)
    count += 1
    
total_square_error = 0
for _ in errors:
    total_square_error += _ ** 2
    
mean_square_error = total_square_error/len(pred_list)
print(mean_square_error)
# Out:
# 6.17837367654947

# %%
X = wine.drop('quality', axis = 1)
y = wine['quality']

X_train, X_test, y_train, y_test =train_test_split(X, y)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
pred_list = predicted.astype(list)
errors = []
y_test_list

GBR = GradientBoostingRegressor(loss = 'huber', alpha = 0.58, learning_rate = 0.02, n_estimators = 200, subsample = 1)

GBR.fit(X_train, y_train)
predicted = GBR.predict(X_test)

for _ in y_test:
    y_test_list.append(_)
    
errors = []   
count = 0
for _ in pred_list:
    abs_error = abs(pred_list[count] - y_test_list[count])/y_test_list[count]
    errors.append(abs_error)
    count += 1

total_error = 0
for _ in errors:
    total_error += _ 
    
mape = total_error / len(errors)
print(mape)
#count = 0
#for _ in pred_list:
#    error = pred_list[count] - y_test_list[count]
#    errors.append(error)
#    count += 1
    
#total_square_error = 0
#for _ in errors:
    #total_square_error += _ ** 2
    
#mean_square_error = total_square_error/len(pred_list)
#print(mean_square_error)
# Out:
# 0.12990778195830413

# %%
fig1 = plt.figure(1, figsize=(20,5))
chart1 = fig1.add_subplot(121)


xx = [3,4,5,6,7,8]
yy = [3,4,5,6,7,8]

chart1.set_xlabel('Actual Score')
chart1.set_ylabel('Predicted Score')

chart1.scatter(y_test,predicted)
chart1.plot(xx,yy)
